# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv("CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels= False , cbar=False)
# Out:
# <Axes: >

# %%
df['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
sns.set_style('whitegrid')
sns.countplot(x='fueltype',data=df)
# Out:
# <Axes: xlabel='fueltype', ylabel='count'>

# %%
sns.countplot(x='doornumber',data=df)
# Out:
# <Axes: xlabel='doornumber', ylabel='count'>

# %%
sns.countplot(x='aspiration',data=df)
# Out:
# <Axes: xlabel='aspiration', ylabel='count'>

# %%
sns.countplot(x='carbody',data=df)
# Out:
# <Axes: xlabel='carbody', ylabel='count'>

# %%
sns.histplot(data=df, x="wheelbase", kde=True, element="poly")
# Out:
# <Axes: xlabel='wheelbase', ylabel='Count'>

# %%
sns.displot(data=df, x="carlength", kind='kde')

# %%
sns.displot(data=df, x="carwidth", kind='kde')

# %%
df['enginetype'].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
df['enginelocation'].value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
sns.displot(data=df, x="horsepower", hue="cylindernumber", kind="ecdf")

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['gas']= df.fueltype.apply(lambda x: 1 if x=="gas" else 0)

# %%
df['door_number']= df.doornumber.apply(lambda x: 2 if x=="two" else 4)

# %%
df['aspiration_std']= df.aspiration.apply(lambda x: 1 if x=="std" else 0)

# %%
le_car_body= LabelEncoder()
df['car_body']=le_car_body.fit_transform(df['carbody'])

# %%
le_engine_type= LabelEncoder()
df['engine_type']=le_engine_type.fit_transform(df['enginetype'])

# %%
df.drop(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody','enginelocation', 'enginetype' ],axis=1, inplace=True)

# %%
le_engine_type= LabelEncoder()
df['engine_type']=le_engine_type.fit_transform(df['enginetype'])
# Out:
#    car_ID  symboling drivewheel  wheelbase  carlength  carwidth  carheight  \
# 0       1          3        rwd       88.6      168.8      64.1       48.8
# 1       2          3        rwd       88.6      168.8      64.1       48.8
# 2       3          1        rwd       94.5      171.2      65.5       52.4
# 3       4          2        fwd       99.8      176.6      66.2       54.3
# 4       5          2        4wd       99.4      176.6      66.4       54.3
#
#    curbweight cylindernumber  enginesize  ... horsepower  peakrpm  citympg  \
# 0        2548           four         130  ...        111     5000       21
# 1        2548           four         130  ...        111     5000       21
# 2        2823            six         152  ...        154     5000       19
# 3        2337           four         109  ...        102     5500       24
# 4        2824           five         136  ...        115     5500       18
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   drivewheel        205 non-null    object
#  3   wheelbase         205 non-null    float64
#  4   carlength         205 non-null    float64
#  5   carwidth          205 non-null    float64
#  6   carheight         205 non-null    float64
#  7   curbweight        205 non-null    int64
#  8   cylindernumber    205 non-null    object
#  9   enginesize        205 non-null    int64
#  10  fuelsystem        205 non-null    object
#  11  boreratio         205 non-null    float64
#  12  stroke            205 non-null    float64
#  13  compressionratio  205 non-null    float64
#  14  horsepower        205 non-null    int64
#  15  peakrpm           205 non-null    int64
# ...

# %%
plt.figure(figsize=(12, 10))

sns.heatmap(df.corr(), annot=True, cmap='summer')
plt.title('Correlation parameters with price')
# Out:
# C:\Users\Srishti\AppData\Local\Temp\ipykernel_2852\2049507810.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='summer')
# Text(0.5, 1.0, 'Correlation parameters with price')

# %%
df.drop(['car_ID', 'symboling', 'carheight', 'stroke', 'compressionratio', 'peakrpm','gas', 'door_number','aspiration_std','car_body','engine_type'], axis=1, inplace=True)

# %%
df['fuelsystem'].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
le_fuel_system= LabelEncoder()
df['fuel_system']=le_fuel_system.fit_transform(df['fuelsystem'])

# %%
df.drop(['fuelsystem'], axis=1, inplace=True)

# %%
sns.heatmap(df.corr(), annot=True, cmap='summer')
plt.title('Correlation parameters with price')
# Out:
# Text(0.5, 1.0, 'Correlation parameters with price')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['price'], axis=1)
y=df['price']

# %%
x.head()
# Out:
#    wheelbase  carlength  carwidth  curbweight  enginesize  boreratio  \
# 0       88.6      168.8      64.1        2548         130       3.47
# 1       88.6      168.8      64.1        2548         130       3.47
# 2       94.5      171.2      65.5        2823         152       2.68
# 3       99.8      176.6      66.2        2337         109       3.19
# 4       99.4      176.6      66.4        2824         136       3.19
#
#    horsepower  citympg  highwaympg  fuel_system
# 0         111       21          27            5
# 1         111       21          27            5
# 2         154       19          26            5
# 3         102       24          30            5
# 4         115       18          22            5

# %%
X_train,X_test, y_train, y_test= train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, classification_report, confusion_matrix
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
model= LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.877105265489282

# %%
y_pre = model.predict(X_test)

# %%
y_test.dtype
# Out:
# dtype('float64')

# %%
y_pre.dtype
# Out:
# dtype('float64')

# %%
print(r2_score(y_test, y_pre))
# Out:
# 0.877105265489282
